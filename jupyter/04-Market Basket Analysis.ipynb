# %% [markdown]
# # Market Basket Analysis

# %% [markdown]
# Market basket analysis scrutinizes the products customers tend to buy together, and uses the information to decide which products should be cross-sold or promoted together. The term arises from the shopping carts supermarket shoppers fill up during a shopping trip.
#
# Association Rule Mining is used when we want to find an association between different objects in a set, find frequent patterns in a transaction database, relational databases or any other information repository.
#
# The most common approach to find these patterns is Market Basket Analysis, which is a key technique used by large retailers like Amazon, Flipkart, etc to analyze customer buying habits by finding associations between the different items that customers place in their “shopping baskets”. The discovery of these associations can help retailers develop marketing strategies by gaining insight into which items are frequently purchased together by customers. The strategies may include:
#
# - Changing the store layout according to trends
# - Customers behavior analysis
# - Catalog Design
# - Cross marketing on online stores
# - Customized emails with add-on sales, etc.

# %% [markdown]
# ### Matrices
#
# - **Support** : Its the default popularity of an item. In mathematical terms, the support of item A is the ratio of transactions involving A to the total number of transactions.
#
#
# - **Confidence** : Likelihood that customer who bought both A and B. It is the ratio of the number of transactions involving both A and B and the number of transactions involving B.
#      - Confidence(A => B) = Support(A, B)/Support(A)
#
#
# - **Lift** : Increase in the sale of A when you sell B.
#
#     - Lift(A => B) = Confidence(A, B)/Support(B)
#
#     - Lift (A => B) = 1 means that there is no correlation within the itemset.
#     - Lift (A => B) > 1 means that there is a positive correlation within the itemset, i.e., products in the itemset, A, and B, are more likely to be bought together.
#     - Lift (A => B) < 1 means that there is a negative correlation within the itemset, i.e., products in itemset, A, and B, are unlikely to be bought together.

# %% [markdown]
# **Apriori Algorithm:** Apriori algorithm assumes that any subset of a frequent itemset must be frequent. Its the algorithm behind Market Basket Analysis. Say, a transaction containing {Grapes, Apple, Mango} also contains {Grapes, Mango}. So, according to the principle of Apriori, if {Grapes, Apple, Mango} is frequent, then {Grapes, Mango} must also be frequent.

# %%
# !pip install presto-python-client
# !pip install pandas plotnine
# !pip install mlxtend

import prestodb
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# Requirement already satisfied: presto-python-client in /opt/conda/lib/python3.10/site-packages (0.8.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from presto-python-client) (8.1.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from presto-python-client) (1.16.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from presto-python-client) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.10/site-packages (from requests->presto-python-client) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->presto-python-client) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->presto-python-client) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->presto-python-client) (2022.5.18.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: plotnine in /opt/conda/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.10/site-packages (from pandas) (1.21.6)
# Requirement already satisfied: matplotlib>=3.5.0 in /opt/conda/lib/python3.10/site-packages (from plotnine) (3.5.2)
# Requirement already satisfied: patsy>=0.5.1 in /opt/conda/lib/python3.10/site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: scipy>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from plotnine) (1.8.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from plotnine) (0.13.2)
# Requirement already satisfied: mizani>=0.7.3 in /opt/conda/lib/python3.10/site-packages (from plotnine) (0.7.4)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (4.33.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.5.0->plotnine) (9.1.1)
# Requirement already satisfied: palettable in /opt/conda/lib/python3.10/site-packages (from mizani>=0.7.3->plotnine) (3.3.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Requirement already satisfied: mlxtend in /opt/conda/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: scipy>=1.2.1 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.8.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (3.5.2)
# Requirement already satisfied: pandas>=0.24.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: joblib>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from mlxtend) (62.6.0)
# Requirement already satisfied: numpy>=1.16.2 in /opt/conda/lib/python3.10/site-packages (from mlxtend) (1.21.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (4.33.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (9.1.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %% [markdown]
# ### Data

# %%
# limit the data to 1M rows for avoid OFME
conn=prestodb.dbapi.connect(
    host='presto-service',
    port=8282,
    user='presto',
    catalog='hive',
    schema='sample',
)

fetchlimit = 100000

cur = conn.cursor()
cur.execute('show tables')
pd.DataFrame.from_records(cur.fetchall(), columns = [i[0] for i in cur.description])
# Out:
#                       Table
# 0  avg_product_count_by_dow
# 1            order_products
# 2             product_count
# 3        stg_order_products
# 4                stg_orders
# 5      top_selling_products

# %%
cur.execute('select * from sample.order_products limit ' + str(fetchlimit))
order_products = pd.DataFrame.from_records(cur.fetchall(), columns = [i[0] for i in cur.description])
order_products.shape
# Out:
# (100000, 21)

# %%
order_products.head()
# Out:
#   _hoodie_commit_time         _hoodie_commit_seqno  \
# 0   20220715145217724  20220715145217724_74_156134
# 1   20220715145217724  20220715145217724_74_156135
# 2   20220715145217724  20220715145217724_74_156136
# 3   20220715145217724  20220715145217724_74_156137
# 4   20220715145217724  20220715145217724_74_156138
#
#                   _hoodie_record_key _hoodie_partition_path  \
# 0   order_id:2140546,product_id:7361
# 1   order_id:2140546,product_id:7649
# 2  order_id:2140575,product_id:13799
# 3  order_id:2140575,product_id:18477
# 4  order_id:2140575,product_id:18610
#
#                                    _hoodie_file_name  order_id  user_id  \
# 0  61cf5a4c-8127-4750-b285-a40163da5747-0_74-500-...   2140546    58491
# 1  61cf5a4c-8127-4750-b285-a40163da5747-0_74-500-...   2140546    58491
# 2  61cf5a4c-8127-4750-b285-a40163da5747-0_74-500-...   2140575   143455
# 3  61cf5a4c-8127-4750-b285-a40163da5747-0_74-500-...   2140575   143455
# 4  61cf5a4c-8127-4750-b285-a40163da5747-0_74-500-...   2140575   143455
#
#    order_number  order_dow  order_hour_of_day  ...  \
# 0            25          6                 15  ...
# 1            25          6                 15  ...
# 2             1          6                 14  ...
# 3             1          6                 14  ...
# 4             1          6                 14  ...
#
#    days_since_prior_order_cum               order_date product_id  \
# 0                       103.0  2020-04-14 07:00:00.000       7361
# 1                       103.0  2020-04-14 07:00:00.000       7649
# 2                         0.0  2020-01-07 06:00:00.000      13799
# 3                         0.0  2020-01-07 06:00:00.000      18477
# 4                         0.0  2020-01-07 06:00:00.000      18610
#
#    add_to_cart_order  reordered               product_name aisle_id  \
# 0                  4       True              Herb Crackers     78.0
# 1                 14      False  Whole Wheat Tandoori Naan    128.0
# 2                  4      False      42.2 Oz Wj Rf Lav&Van    114.0
# 3                  8      False      Ground Round 85% Lean    122.0
# 4                  1      False                  Cola Soda     77.0
#
#                   aisle department_id    department
# 0              crackers          19.0        snacks
# 1  tortillas flat bread           3.0        bakery
# 2     cleaning products          17.0     household
# 3          meat counter          12.0  meat seafood
# 4           soft drinks           7.0     beverages
#
# [5 rows x 21 columns]

# %%
order_products.product_id.nunique()
# Out:
# 15146

# %%
products = order_products.groupby(['product_id', 'product_name', 'aisle_id', 'department_id']).size().to_frame('order_count').reset_index()
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies      61.0
# 1           4  Smart Ones Classic Favorites Mini Rigatoni Wit...      38.0
# 2           9                  Light Strawberry Blueberry Yogurt     120.0
# 3          10     Sparkling Orange Juice & Prickly Pear Beverage     115.0
# 4          16                      Mint Chocolate Flavored Syrup     103.0
#
#    department_id  count
# 0           19.0      6
# 1            1.0      1
# 2           16.0      1
# 3            7.0      9
# 4           19.0      1

# %% [markdown]
# Out of 49685 keeping top 100 most frequent products.

# %%
product_counts = order_products.groupby('product_id')['order_id'].count().reset_index().rename(columns = {'order_id':'frequency'})
product_counts = product_counts.sort_values('frequency', ascending=False)[0:100].reset_index(drop = True)
product_counts = product_counts.merge(products, on = 'product_id', how = 'left')
product_counts.head(10)
# Out:
#    product_id  frequency            product_name  aisle_id  department_id  \
# 0       24852       1550                  Banana      24.0            4.0
# 1       13176       1179  Bag of Organic Bananas      24.0            4.0
# 2       21137        768    Organic Strawberries      24.0            4.0
# 3       21903        763    Organic Baby Spinach     123.0            4.0
# 4       47209        650    Organic Hass Avocado      24.0            4.0
# 5       47766        594         Organic Avocado      24.0            4.0
# 6       47626        487             Large Lemon      24.0            4.0
# 7       26209        470                   Limes      24.0            4.0
# 8       16797        427            Strawberries      24.0            4.0
# 9       27845        421      Organic Whole Milk      84.0           16.0
#
#     count
# 0  1550.0
# 1  1179.0
# 2   768.0
# 3   763.0
# 4   650.0
# 5   594.0
# 6   487.0
# 7   470.0
# 8   427.0
# 9   421.0

# %% [markdown]
# Keeping 100 most frequent items in order_products dataframe

# %%
freq_products = list(product_counts.product_id)
freq_products[1:10]
# Out:
# [13176, 21137, 21903, 47209, 47766, 47626, 26209, 16797, 27845]

# %%
len(freq_products)
# Out:
# 100

# %%
order_products = order_products[order_products.product_id.isin(freq_products)]
order_products.shape
# Out:
# (23591, 21)

# %%
order_products.order_id.nunique()
# Out:
# 7250

# %%
order_products.head()
# Out:
#    _hoodie_commit_time         _hoodie_commit_seqno  \
# 23   20220715145217724  20220715145217724_74_156157
# 24   20220715145217724  20220715145217724_74_156158
# 37   20220715145217724  20220715145217724_74_156171
# 41   20220715145217724  20220715145217724_74_156175
# 53   20220715145217724  20220715145217724_74_156187
#
#                    _hoodie_record_key _hoodie_partition_path  \
# 23   order_id:214065,product_id:21903
# 24   order_id:214065,product_id:22935
# 37   order_id:2140653,product_id:5785
# 41  order_id:2140777,product_id:21137
# 53  order_id:2140828,product_id:21903
#
#                                     _hoodie_file_name  order_id  user_id  \
# 23  61cf5a4c-8127-4750-b285-a40163da5747-0_74-500-...    214065   157347
# 24  61cf5a4c-8127-4750-b285-a40163da5747-0_74-500-...    214065   157347
# 37  61cf5a4c-8127-4750-b285-a40163da5747-0_74-500-...   2140653   186889
# 41  61cf5a4c-8127-4750-b285-a40163da5747-0_74-500-...   2140777   142850
# 53  61cf5a4c-8127-4750-b285-a40163da5747-0_74-500-...   2140828   190693
#
#     order_number  order_dow  order_hour_of_day  ...  \
# 23             3          5                 15  ...
# 24             3          5                 15  ...
# 37            22          6                 14  ...
# 41            13          2                 23  ...
# 53            23          4                  8  ...
#
#     days_since_prior_order_cum               order_date product_id  \
# 23                        19.0  2020-02-24 07:00:00.000      21903
# 24                        19.0  2020-02-24 07:00:00.000      22935
# 37                       285.0  2020-11-16 06:00:00.000       5785
# 41                       100.0  2020-04-10 15:00:00.000      21137
# 53                       210.0  2020-08-02 00:00:00.000      21903
#
#     add_to_cart_order  reordered                 product_name aisle_id  \
# 23                  5      False         Organic Baby Spinach    123.0
# 24                  4      False         Organic Yellow Onion     83.0
# 37                  3       True  Organic Reduced Fat 2% Milk     84.0
# 41                  2       True         Organic Strawberries     24.0
# 53                  9      False         Organic Baby Spinach    123.0
#
#                          aisle department_id  department
# 23  packaged vegetables fruits           4.0     produce
# 24            fresh vegetables           4.0     produce
# 37                        milk          16.0  dairy eggs
# 41                fresh fruits           4.0     produce
# 53  packaged vegetables fruits           4.0     produce
#
# [5 rows x 21 columns]

# %% [markdown]
# Structuring the data for feeding in the algorithm

# %%
basket = order_products.groupby(['order_id', 'product_name'])['reordered'].count().unstack().reset_index().fillna(0).set_index('order_id')
basket.head()
# Out:
# product_name  "Clementines  100% Raw Coconut Water  100% Whole Wheat Bread  \
# order_id
# 359                    0.0                     0.0                     0.0
# 1157                   0.0                     0.0                     0.0
# 1804                   0.0                     0.0                     0.0
# 2849                   0.0                     0.0                     0.0
# 3655                   0.0                     0.0                     0.0
#
# product_name  2% Reduced Fat Milk  Apple Honeycrisp Organic  Asparagus  \
# order_id
# 359                           0.0                       0.0        1.0
# 1157                          0.0                       0.0        0.0
# 1804                          0.0                       0.0        0.0
# 2849                          0.0                       0.0        0.0
# 3655                          0.0                       0.0        0.0
#
# product_name  Bag of Organic Bananas  Banana  Bartlett Pears  Blueberries  \
# order_id
# 359                              0.0     0.0             0.0          0.0
# 1157                             0.0     1.0             0.0          0.0
# 1804                             0.0     0.0             0.0          0.0
# 2849                             0.0     1.0             0.0          0.0
# 3655                             0.0     0.0             0.0          0.0
#
# product_name  ...  Sparkling Lemon Water  Sparkling Natural Mineral Water  \
# order_id      ...
# 359           ...                    1.0                              0.0
# 1157          ...                    0.0                              0.0
# 1804          ...                    0.0                              0.0
# 2849          ...                    0.0                              0.0
# 3655          ...                    0.0                              0.0
#
# product_name  Sparkling Water Grapefruit  Spring Water  Strawberries  \
# order_id
# 359                                  1.0           0.0           0.0
# 1157                                 0.0           0.0           0.0
# 1804                                 0.0           0.0           0.0
# 2849                                 0.0           0.0           0.0
# 3655                                 0.0           0.0           0.0
#
# product_name  Uncured Genoa Salami  Unsalted Butter  Unsweetened Almondmilk  \
# order_id
# 359                            0.0              0.0                     0.0
# 1157                           0.0              0.0                     0.0
# 1804                           0.0              0.0                     0.0
# 2849                           0.0              0.0                     0.0
# 3655                           0.0              0.0                     0.0
#
# product_name  Unsweetened Original Almond Breeze Almond Milk  Yellow Onions
# order_id
# 359                                                      0.0            0.0
# 1157                                                     0.0            0.0
# 1804                                                     0.0            0.0
# 2849                                                     0.0            0.0
# 3655                                                     0.0            0.0
#
# [5 rows x 100 columns]

# %%
del product_counts, products, order_products
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 del product_counts, products, order_products, order_products_prior, order_products_train
#
# NameError: name 'order_products_prior' is not defined

# %% [markdown]
# encoding the units

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1 
    
basket = basket.applymap(encode_units)
basket.head()

# %%
basket.size

# %%
basket.shape

# %% [markdown]
# Creating frequent sets and rules

# %%
frequent_items = apriori(basket, min_support=0.01, use_colnames=True, low_memory=True)
frequent_items.head()

# %%
frequent_items.tail()

# %%
frequent_items.shape

# %%
rules = association_rules(frequent_items, metric="lift", min_threshold=1)
rules.sort_values('lift', ascending=False)

# %%
conn.close()
